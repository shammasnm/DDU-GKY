# %%
import pandas as pd
import 
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("C:\\Users\\USER\\DA\\Data Sets\\Car_sales.csv")

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data.dropna(inplace=True)

# %% [markdown]
# # Checking the contents in latest launch columns

# %%
data.Latest_Launch.unique()
# Out:
# array(['2012-02-02T00:00:00.000000000', '2011-06-03T00:00:00.000000000',
#        '2011-03-10T00:00:00.000000000', '2011-10-08T00:00:00.000000000',
#        '2011-08-09T00:00:00.000000000', '2012-02-27T00:00:00.000000000',
#        '2012-01-29T00:00:00.000000000', '2011-04-04T00:00:00.000000000',
#        '2011-11-02T00:00:00.000000000', '2011-09-03T00:00:00.000000000',
#        '2012-03-23T00:00:00.000000000', '2011-07-23T00:00:00.000000000',
#        '2012-02-23T00:00:00.000000000', '2011-11-27T00:00:00.000000000',
#        '2011-09-28T00:00:00.000000000', '2011-08-17T00:00:00.000000000',
#        '2012-03-19T00:00:00.000000000', '2011-05-24T00:00:00.000000000',
#        '2011-12-22T00:00:00.000000000', '2011-10-23T00:00:00.000000000',
#        '2012-05-12T00:00:00.000000000', '2011-09-11T00:00:00.000000000',
#        '2012-04-13T00:00:00.000000000', '2012-01-16T00:00:00.000000000',
#        '2011-11-17T00:00:00.000000000', '2012-06-06T00:00:00.000000000',
# ...

# %% [markdown]
# # change its datatype into date time

# %%
data["Latest_Launch"]=pd.to_datetime(data.Latest_Launch)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %% [markdown]
# # Extracting year,month,date from the Latest_Launch column

# %%
data["year"]=pd.DatetimeIndex(data.Latest_Launch).year

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data["month"]=pd.DatetimeIndex(data.Latest_Launch).month

# %%
data["day"]=pd.DatetimeIndex(data.Latest_Launch).day

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.drop(columns="date",inplace=True)

# %% [markdown]
# # Lets convert the data type of fuel efficiency into integer

# %%
data.Fuel_efficiency=data.Fuel_efficiency.astype(int)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int32
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
data.Fuel_efficiency=data.Fuel_efficiency.astype('int64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# # converting the numerical colums into categorical columns

# %%
data.month.replace({
    1:"January",
    2:"February",
    3:"March",
    4:"April",
    5:"May",
    6:"June",
    7:"July",
    8:"August",
    9:"September",
    10:"October",
    11:"November",
    12:"December"
    },inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %% [markdown]
# # Label encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data["Le_Vehicle"]=le.fit_transform(data.Vehicle_type)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data["Le_Vehicle"].unique()
# Out:
# array([1, 0])

# %%
data["Vehicle_type"].unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %%
data[data["Vehicle_type"]=='Car']
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 40         Dodge      Ram Pickup             227.061               15.060
# 41         Dodge       Ram Wagon              16.767               15.510
# 42         Dodge         Ram Van              31.038               13.425
# 43         Dodge          Dakota             111.313               11.260
# 45         Dodge         Caravan             181.749               12.025
# 52          Ford        Explorer             276.747               16.640
# 53          Ford        Windstar             155.787               13.175
# 54          Ford      Expedition             125.338               23.575
# 55          Ford          Ranger             220.650                7.850
# 56          Ford        F-Series             540.561               15.075
# 59         Honda            CR-V              73.203               17.710
# 60         Honda        Passport              12.855               17.525
# ...

# %%
data["Manufacturer"].unique()
# Out:
# 26

# %%
data["Le_Manufacturer"]=le.fit_transform(data.Manufacturer)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data[data["Le_Manufacturer"]==1]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 4         Audi    A4              20.397               22.255    Passenger
# 5         Audi    A6              18.780               23.555    Passenger
# 6         Audi    A8               1.380               39.000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  ...  \
# 4               23.99          1.8       150.0      102.6   68.2  ...
# 5               33.95          2.8       200.0      108.7   76.1  ...
# 6               62.00          4.2       310.0      113.0   74.0  ...
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency  Latest_Launch  \
# 4        2.998           16.4               27     2011-10-08
# 5        3.561           18.5               22     2011-08-09
# 6        3.902           23.7               21     2012-02-27
#
#   Power_perf_factor  year     month day  Le_Vehicle  Le_Manufacturer
# ...

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
data.Horsepower=data.Horsepower.astype("int64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    int64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
data["Model"].unique()
# Out:
# array(['Integra', 'TL', 'RL', 'A4', 'A6', 'A8', '328i', '528i', 'Century',
#        'Regal', 'Park Avenue', 'LeSabre', 'DeVille', 'Eldorado', 'Catera',
#        'Cavalier', 'Malibu', 'Lumina', 'Monte Carlo', 'Camaro',
#        'Corvette', 'Prizm', 'Metro', 'Sebring Coupe', 'Sebring Conv.',
#        'Concorde', 'Cirrus', 'LHS', 'Neon', 'Avenger', 'Stratus', 'Viper',
#        'Ram Pickup', 'Ram Wagon', 'Ram Van', 'Dakota', 'Caravan',
#        'Escort', 'Mustang', 'Contour', 'Taurus', 'Crown Victoria',
#        'Explorer', 'Windstar', 'Expedition', 'Ranger', 'F-Series',
#        'Civic', 'Accord', 'CR-V', 'Passport', 'Odyssey', 'Accent',
#        'Elantra', 'Sonata', 'I30', 'Wrangler', 'Cherokee',
#        'Grand Cherokee', 'ES300', 'GS300', 'LS400', 'Continental',
#        'Town car', 'Mirage', 'Eclipse', 'Galant', 'Diamante', '3000GT',
#        'Montero', 'Montero Sport', 'Mystique', 'Cougar', 'Sable',
#        'Grand Marquis', 'Mountaineer', 'Villager', 'C-Class', 'E-Class',
# ...

# %%
df=pd.read_csv("C:\\Users\\USER\\DA\\Data Sets\\Car_sales.csv")

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df.fillna(df.mean()["__year_resale_value"],inplace=True)

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8       140.0      101.2
# ...

# %%
df.Horsepower=df.Horsepower.astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    int64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df.Fuel_efficiency=df.Fuel_efficiency.astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    int64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    int64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df["Latest_Launch"]=pd.to_datetime(df.Latest_Launch)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    int64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    int64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8         140      101.2
# ...

# %%
df["month"]=pd.DatetimeIndex(df.Latest_Launch).month

# %%
df["day"]=pd.DatetimeIndex(df.Latest_Launch).day
df["year"]=pd.DatetimeIndex(df.Latest_Launch).year

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8         140      101.2
# ...

# %%
df["column"]=df.Latest_Launch

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8         140      101.2
# ...

# %%
df.day=df.day.astype("object")
df.month=df.month.astype("object")
df.year=df.year.astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  157 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   157 non-null    float64
#  6   Engine_size          157 non-null    float64
#  7   Horsepower           157 non-null    int64
#  8   Wheelbase            157 non-null    float64
#  9   Width                157 non-null    float64
#  10  Length               157 non-null    float64
#  11  Curb_weight          157 non-null    float64
#  12  Fuel_capacity        157 non-null    float64
#  13  Fuel_efficiency      157 non-null    int64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
df['row'] = df[['day',"month",'year']].apply('-'.join,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6688\2556766886.py in <module>
# ----> 1 df['row'] = df[['day',"month",'year']].apply('-'.join,axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
# ...

# %%
df['row'] = df[['day',"month",'year']].apply(lambda x: '_'.join(x), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6688\4005648653.py in <module>
# ----> 1 df['row'] = df[['day',"month",'year']].apply(lambda x: '_'.join(x), axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
# ...
